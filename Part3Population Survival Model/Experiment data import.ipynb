# %%
## MG1655 pGEX-4T-1-Csga-MBP3
import csv
f = open('Ag.csv','w',encoding ='utf-8')
csv_writer = csv.writer(f)
csv_writer.writerow(["time","od","treat"])

csv_writer.writerow(["0", "0.016","0"])
csv_writer.writerow(["2", "0.055","0"])
csv_writer.writerow(["4", "0.285","0"])
csv_writer.writerow(["6", "0.461","0"])
csv_writer.writerow(["8", "0.645","0"])
csv_writer.writerow(["17", "0.882","0"])
csv_writer.writerow(["19", "0.918","0"])
csv_writer.writerow(["21", "0.917","0"])
csv_writer.writerow(["23", "0.905","0"])
csv_writer.writerow(["25", "0.905","0"])
csv_writer.writerow(["27", "0.924","0"])
csv_writer.writerow(["29", "0.856","0"])
csv_writer.writerow(["31", "0.781","0"])

csv_writer.writerow(["0", "0.02","5"])
csv_writer.writerow(["2", "0.031","5"])
csv_writer.writerow(["4", "0.188","5"])
csv_writer.writerow(["6", "0.419","5"])
csv_writer.writerow(["8", "0.602","5"])
csv_writer.writerow(["17", "0.867","5"])
csv_writer.writerow(["19", "0.907","5"])
csv_writer.writerow(["21", "0.907","5"])
csv_writer.writerow(["23", "0.896","5"])
csv_writer.writerow(["25", "0.891","5"])
csv_writer.writerow(["27", "0.910","5"])
csv_writer.writerow(["29", "0.929","5"])
csv_writer.writerow(["31", "0.801","5"])

csv_writer.writerow(["0", "0.017","10"])
csv_writer.writerow(["2", "0.02","10"])
csv_writer.writerow(["4", "0.102","10"])
csv_writer.writerow(["6", "0.335","10"])
csv_writer.writerow(["8", "0.557","10"])
csv_writer.writerow(["17", "0.831","10"])
csv_writer.writerow(["19", "0.879","10"])
csv_writer.writerow(["21", "0.895","10"])
csv_writer.writerow(["23", "0.897","10"])
csv_writer.writerow(["25", "0.908","10"])
csv_writer.writerow(["27", "0.959","10"])
csv_writer.writerow(["29", "0.936","10"])
csv_writer.writerow(["31", "0.882","10"])

csv_writer.writerow(["0", "0.017","20"])
csv_writer.writerow(["2", "0.016","20"])
csv_writer.writerow(["4", "0.030","20"])
csv_writer.writerow(["6", "0.175","20"])
csv_writer.writerow(["8", "0.499","20"])
csv_writer.writerow(["17", "0.744","20"])
csv_writer.writerow(["19", "0.800","20"])
csv_writer.writerow(["21", "0.840","20"])
csv_writer.writerow(["23", "0.863","20"])
csv_writer.writerow(["25", "0.881","20"])
csv_writer.writerow(["27", "0.949","20"])
csv_writer.writerow(["29", "0.930","20"])
csv_writer.writerow(["31", "0.922","20"])

csv_writer.writerow(["0", "0.017","40"])
csv_writer.writerow(["2", "0.013","40"])
csv_writer.writerow(["4", "0.011","40"])
csv_writer.writerow(["6", "0.008","40"])
csv_writer.writerow(["8", "0.099","40"])
csv_writer.writerow(["17", "0.481","40"])
csv_writer.writerow(["19", "0.571","40"])
csv_writer.writerow(["21", "0.646","40"])
csv_writer.writerow(["23", "0.721","40"])
csv_writer.writerow(["25", "0.774","40"])
csv_writer.writerow(["27", "0.920","40"])
csv_writer.writerow(["29", "0.881","40"])
csv_writer.writerow(["31", "0.949","40"])

csv_writer.writerow(["0", "0.015","80"])
csv_writer.writerow(["2", "0.012","80"])
csv_writer.writerow(["4", "0.008","80"])
csv_writer.writerow(["6", "0.003","80"])
csv_writer.writerow(["8", "0.095","80"])
csv_writer.writerow(["17", "0.029","80"])
csv_writer.writerow(["19", "0.033","80"])
csv_writer.writerow(["21", "0.123","80"])
csv_writer.writerow(["23", "0.411","80"])
csv_writer.writerow(["25", "0.597","80"])
csv_writer.writerow(["27", "0.792","80"])
csv_writer.writerow(["29", "0.779","80"])
csv_writer.writerow(["31", "0.881","80"])
# Out:
# 13

# %%
## MG1655
import csv
f = open('Ag1.csv','w',encoding ='utf-8')
csv_writer = csv.writer(f)
csv_writer.writerow(["time","od","treat"])

csv_writer.writerow(["0", "0.017","0"])
csv_writer.writerow(["2", "0.160","0"])
csv_writer.writerow(["4", "0.502","0"])
csv_writer.writerow(["6", "0.559","0"])
csv_writer.writerow(["8", "0.765","0"])
csv_writer.writerow(["17", "0.951","0"])
csv_writer.writerow(["19", "1.009","0"])
csv_writer.writerow(["21", "1.009","0"])
csv_writer.writerow(["23", "1.019","0"])
csv_writer.writerow(["25", "1.066","0"])
csv_writer.writerow(["27", "0.951","0"])
csv_writer.writerow(["29", "0.967","0"])
csv_writer.writerow(["31", "0.724","0"])

csv_writer.writerow(["0", "0.020","5"])
csv_writer.writerow(["2", "0.114","5"])
csv_writer.writerow(["4", "0.469","5"])
csv_writer.writerow(["6", "0.520","5"])
csv_writer.writerow(["8", "0.731","5"])
csv_writer.writerow(["17", "0.944","5"])
csv_writer.writerow(["19", "0.986","5"])
csv_writer.writerow(["21", "0.981","5"])
csv_writer.writerow(["23", "0.988","5"])
csv_writer.writerow(["25", "1.030","5"])
csv_writer.writerow(["27", "0.875","5"])
csv_writer.writerow(["29", "0.916","5"])
csv_writer.writerow(["31", "0.753","5"])

csv_writer.writerow(["0", "0.018","10"])
csv_writer.writerow(["2", "0.065","10"])
csv_writer.writerow(["4", "0.399","10"])
csv_writer.writerow(["6", "0.478","10"])
csv_writer.writerow(["8", "0.699","10"])
csv_writer.writerow(["17", "0.933","10"])
csv_writer.writerow(["19", "0.958","10"])
csv_writer.writerow(["21", "0.957","10"])
csv_writer.writerow(["23", "0.977","10"])
csv_writer.writerow(["25", "1.002","10"])
csv_writer.writerow(["27", "0.965","10"])
csv_writer.writerow(["29", "0.920","10"])
csv_writer.writerow(["31", "0.800","10"])

csv_writer.writerow(["0", "0.021","20"])
csv_writer.writerow(["2", "0.040","20"])
csv_writer.writerow(["4", "0.219","20"])
csv_writer.writerow(["6", "0.439","20"])
csv_writer.writerow(["8", "0.558","20"])
csv_writer.writerow(["17", "0.892","20"])
csv_writer.writerow(["19", "0.965","20"])
csv_writer.writerow(["21", "0.958","20"])
csv_writer.writerow(["23", "0.980","20"])
csv_writer.writerow(["25", "0.988","20"])
csv_writer.writerow(["27", "0.971","20"])
csv_writer.writerow(["29", "0.920","20"])
csv_writer.writerow(["31", "0.940","20"])

csv_writer.writerow(["0", "0.020","40"])
csv_writer.writerow(["2", "0.027","40"])
csv_writer.writerow(["4", "0.020","40"])
csv_writer.writerow(["6", "0.010","40"])
csv_writer.writerow(["8", "0.110","40"])
csv_writer.writerow(["17", "0.790","40"])
csv_writer.writerow(["19", "0.881","40"])
csv_writer.writerow(["21", "0.917","40"])
csv_writer.writerow(["23", "0.956","40"])
csv_writer.writerow(["25", "0.982","40"])
csv_writer.writerow(["27", "1.021","40"])
csv_writer.writerow(["29", "0.923","40"])
csv_writer.writerow(["31", "0.990","40"])

csv_writer.writerow(["0", "0.018","80"])
csv_writer.writerow(["2", "0.027","80"])
csv_writer.writerow(["4", "0.019","80"])
csv_writer.writerow(["6", "0.010","80"])
csv_writer.writerow(["8", "0.104","80"])
csv_writer.writerow(["17", "0.042","80"])
csv_writer.writerow(["19", "0.058","80"])
csv_writer.writerow(["21", "0.147","80"])
csv_writer.writerow(["23", "0.452","80"])
csv_writer.writerow(["25", "0.605","80"])
csv_writer.writerow(["27", "0.773","80"])
csv_writer.writerow(["29", "0.798","80"])
csv_writer.writerow(["31", "0.864","80"])
# Out:
# 13

# %%
## MG1655 pGEX-4T-1
import csv
f = open('Ag2.csv','w',encoding ='utf-8')
csv_writer = csv.writer(f)
csv_writer.writerow(["time","od","treat"])

csv_writer.writerow(["0", "0.020","0"])
csv_writer.writerow(["2", "0.171","0"])
csv_writer.writerow(["4", "0.520","0"])
csv_writer.writerow(["6", "0.619","0"])
csv_writer.writerow(["8", "0.798","0"])
csv_writer.writerow(["17", "0.976","0"])
csv_writer.writerow(["19", "1.024","0"])
csv_writer.writerow(["21", "1.016","0"])
csv_writer.writerow(["23", "1.046","0"])
csv_writer.writerow(["25", "1.029","0"])
csv_writer.writerow(["27", "0.995","0"])
csv_writer.writerow(["29", "1.016","0"])
csv_writer.writerow(["31", "0.736","0"])

csv_writer.writerow(["0", "0.020","5"])
csv_writer.writerow(["2", "0.131","5"])
csv_writer.writerow(["4", "0.504","5"])
csv_writer.writerow(["6", "0.586","5"])
csv_writer.writerow(["8", "0.750","5"])
csv_writer.writerow(["17", "0.954","5"])
csv_writer.writerow(["19", "0.998","5"])
csv_writer.writerow(["21", "0.977","5"])
csv_writer.writerow(["23", "1.007","5"])
csv_writer.writerow(["25", "0.977","5"])
csv_writer.writerow(["27", "1.000","5"])
csv_writer.writerow(["29", "1.023","5"])
csv_writer.writerow(["31", "0.815","5"])

csv_writer.writerow(["0", "0.019","10"])
csv_writer.writerow(["2", "0.079","10"])
csv_writer.writerow(["4", "0.414","10"])
csv_writer.writerow(["6", "0.533","10"])
csv_writer.writerow(["8", "0.750","10"])
csv_writer.writerow(["17", "1.013","10"])
csv_writer.writerow(["19", "1.027","10"])
csv_writer.writerow(["21", "1.003","10"])
csv_writer.writerow(["23", "1.044","10"])
csv_writer.writerow(["25", "1.048","10"])
csv_writer.writerow(["27", "1.047","10"])
csv_writer.writerow(["29", "1.028","10"])
csv_writer.writerow(["31", "0.888","10"])

csv_writer.writerow(["0", "0.021","20"])
csv_writer.writerow(["2", "0.050","20"])
csv_writer.writerow(["4", "0.264","20"])
csv_writer.writerow(["6", "0.495","20"])
csv_writer.writerow(["8", "0.670","20"])
csv_writer.writerow(["17", "0.923","20"])
csv_writer.writerow(["19", "0.969","20"])
csv_writer.writerow(["21", "0.955","20"])
csv_writer.writerow(["23", "1.013","20"])
csv_writer.writerow(["25", "1.013","20"])
csv_writer.writerow(["27", "1.051","20"])
csv_writer.writerow(["29", "1.000","20"])
csv_writer.writerow(["31", "0.957","20"])

csv_writer.writerow(["0", "0.024","40"])
csv_writer.writerow(["2", "0.040","40"])
csv_writer.writerow(["4", "0.048","40"])
csv_writer.writerow(["6", "0.114","40"])
csv_writer.writerow(["8", "0.384","40"])
csv_writer.writerow(["17", "0.761","40"])
csv_writer.writerow(["19", "0.854","40"])
csv_writer.writerow(["21", "0.894","40"])
csv_writer.writerow(["23", "0.933","40"])
csv_writer.writerow(["25", "0.974","40"])
csv_writer.writerow(["27", "1.039","40"])
csv_writer.writerow(["29", "0.957","40"])
csv_writer.writerow(["31", "1.010","40"])

csv_writer.writerow(["0", "0.024","80"])
csv_writer.writerow(["2", "0.031","80"])
csv_writer.writerow(["4", "0.025","80"])
csv_writer.writerow(["6", "0.015","80"])
csv_writer.writerow(["8", "0.106","80"])
csv_writer.writerow(["17", "0.054","80"])
csv_writer.writerow(["19", "0.127","80"])
csv_writer.writerow(["21", "0.300","80"])
csv_writer.writerow(["23", "0.526","80"])
csv_writer.writerow(["25", "0.660","80"])
csv_writer.writerow(["27", "0.808","80"])
csv_writer.writerow(["29", "0.787","80"])
csv_writer.writerow(["31", "0.876","80"])
# Out:
# 13
