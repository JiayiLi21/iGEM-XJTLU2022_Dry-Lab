# %%
import numpy as np
import sympy
from scipy.integrate import odeint
import pandas as pd
import matplotlib.pyplot as plt
from scipy import optimize
from scipy.optimize import curve_fit

# %%
df_Ag1 = pd.read_csv('Ag1.csv')

# %%
def model_SAD(I,t,k,A,alpha,beta):
    Na,Ns,Nd = I
    dNa = beta*Ns+k*(1-Na/(A-Nd-Ns))*Na
    dNs = -alpha*Ns-beta*Ns
    dNd = alpha*Ns
    return np.array([dNa,dNs,dNd])
def fit_model_SAD(t,k,A,alpha,beta):
    return odeint(model_SAD,(Na0,Ns0,Nd0),t,args=(k,A,alpha,beta))
def fit_od(t,k,A,alpha,beta):
    return np.sum(fit_model_SAD(t,k,A,alpha,beta),axis=1)
def fit_CFU(t,k,A,alpha,beta):
    return np.sum(fit_model_SAD(t,r,K,alpha,beta)[:,0:2],axis=1)
def Gompertz(t, A, lamta, Um):
    return A*np.exp(-np.exp(Um*np.exp(1)*(lamta-t)/A + 1))

# %%
def R_squared(Y,Y_fitted):
    mean = np.mean(Y)
    ss_tot = np.sum((Y - mean) ** 2)
    ss_res = np.sum((Y - Y_fitted) ** 2)
    r_squared = 1 - (ss_res / ss_tot) 
    return np.round(r_squared,3)

# %%
# Gompertz，find lamta, Um at different Ag ion concentrations
df_Ag1_con = df_Ag1[df_Ag1['treat'] == 0]
time_Ag1 = df_Ag1_con['time']
A = 1.0
popt,pcov = optimize.curve_fit(Gompertz,time_Ag1,df_Ag1_con['od'],p0=(1.0,1.2,2.))
fitted_Gompertz = Gompertz(time_Ag1,*popt)
plt.scatter(time_Ag1,df_Ag1_con['od'],label = 'Original Data')
plt.plot(time_Ag1,fitted_Gompertz,label = 'Gompertz Model')
plt.legend()
plt.title('$R^2$:'+str(R_squared(df_Ag1_con['od'],fitted_Gompertz)))
popt
# Out:
# /Users/alice/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# array([0.96265167, 0.45517927, 0.11741179])

# %%
df_Ag1_con = df_Ag1[df_Ag1['treat'] == 5]
time_Ag1 = df_Ag1_con['time']
A = 1.0
popt,pcov = optimize.curve_fit(Gompertz,time_Ag1,df_Ag1_con['od'],p0=(1.0,1.2,2.))
fitted_Gompertz = Gompertz(time_Ag1,*popt)
plt.scatter(time_Ag1,df_Ag1_con['od'],label = 'Original Data')
plt.plot(time_Ag1,fitted_Gompertz,label = 'Gompertz Model')
plt.legend()
plt.title('$R^2$:'+str(R_squared(df_Ag1_con['od'],fitted_Gompertz)))
popt
# Out:
# /Users/alice/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# array([0.93471636, 0.73061986, 0.11513434])

# %%
df_Ag1_con = df_Ag1[df_Ag1['treat'] == 10]
time_Ag1 = df_Ag1_con['time']
A = 1.0
popt,pcov = optimize.curve_fit(Gompertz,time_Ag1,df_Ag1_con['od'],p0=(1.0,1.2,2.))
fitted_Gompertz = Gompertz(time_Ag1,*popt)
plt.scatter(time_Ag1,df_Ag1_con['od'],label = 'Original Data')
plt.plot(time_Ag1,fitted_Gompertz,label = 'Gompertz Model')
plt.legend()
plt.title('$R^2$:'+str(R_squared(df_Ag1_con['od'],fitted_Gompertz)))
popt
# Out:
# /Users/alice/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# array([0.94169031, 1.18676036, 0.11239169])

# %%
df_Ag1_con = df_Ag1[df_Ag1['treat'] == 20]
time_Ag1 = df_Ag1_con['time']
A = 1.0
popt,pcov = optimize.curve_fit(Gompertz,time_Ag1,df_Ag1_con['od'],p0=(1.0,1.2,2.))
fitted_Gompertz = Gompertz(time_Ag1,*popt)
plt.scatter(time_Ag1,df_Ag1_con['od'],label = 'Original Data')
plt.plot(time_Ag1,fitted_Gompertz,label = 'Gompertz Model')
plt.legend()
plt.title('$R^2$:'+str(R_squared(df_Ag1_con['od'],fitted_Gompertz)))
popt
# Out:
# /Users/alice/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# array([0.96273778, 1.86009993, 0.09797084])

# %%
df_Ag1_con = df_Ag1[df_Ag1['treat'] == 40]
time_Ag1 = df_Ag1_con['time']
A = 1.0
popt,pcov = optimize.curve_fit(Gompertz,time_Ag1,df_Ag1_con['od'],p0=(1.0,1.2,2.))
fitted_Gompertz = Gompertz(time_Ag1,*popt)
plt.scatter(time_Ag1,df_Ag1_con['od'],label = 'Original Data')
plt.plot(time_Ag1,fitted_Gompertz,label = 'Gompertz Model')
plt.legend()
plt.title('$R^2$:'+str(R_squared(df_Ag1_con['od'],fitted_Gompertz)))
popt
# Out:
# /Users/alice/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# array([0.99265604, 7.29636698, 0.09566217])
